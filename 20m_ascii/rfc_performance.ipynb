# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import MonthLocator, YearLocator

# %%
#open csv
data = '/Users/meganmason491/Documents/research/sierra/analysis/results/tmp/SDV_peak_featureImportance.csv'

# %%
df = pd.read_csv(data, index_col='Date')
df = df.drop(['Unnamed: 0'], axis=1)
df.head()
# Out:
#             RFC Accuracy (%)  Elevation Importance (%)  Aspect Importance (%)  \
# Date
# 2013-04-03              30.0                      36.0                   32.0
# 2014-04-07              31.0                      38.0                   32.0
# 2015-03-06              32.0                      36.0                   33.0
# 2016-04-16              30.0                      36.0                   32.0
# 2017-04-01              33.0                      38.0                   31.0
#
#             Slope Importance (%)
# Date
# 2013-04-03                  32.0
# 2014-04-07                  31.0
# 2015-03-06                  31.0
# 2016-04-16                  32.0
# 2017-04-01                  31.0

# %%
df.describe()
# Out:
#        RFC Accuracy (%)  Elevation Importance (%)  Aspect Importance (%)  \
# count          6.000000                  6.000000               6.000000
# mean          32.000000                 37.000000              32.000000
# std            2.280351                  1.095445               0.632456
# min           30.000000                 36.000000              31.000000
# 25%           30.250000                 36.000000              32.000000
# 50%           31.500000                 37.000000              32.000000
# 75%           32.750000                 38.000000              32.000000
# max           36.000000                 38.000000              33.000000
#
#        Slope Importance (%)
# count              6.000000
# mean              31.166667
# std                0.752773
# min               30.000000
# 25%               31.000000
# 50%               31.000000
# 75%               31.750000
# max               32.000000

# %%
ax = df.plot(marker='o', linestyle='', figsize=(20,8))

yloc = YearLocator(base=1, month=1, day=1)

ax.yaxis.set_major_locator(yloc)
plt.grid(axis='x', color='k', which='major', linestyle='-', linewidth=2)
ax.grid(True)

# %%
df.plot(marker='o', figsize=(20,8))
