# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import MonthLocator, YearLocator

# %%
#open csv
data = '/Users/meganmason491/Documents/research/sierra/analysis/results/tmp/featureImportance.csv'

# %%
df = pd.read_csv(data, index_col='Date')
df = df.drop(['Unnamed: 0'], axis=1)
df.head()
# Out:
#             RFC Accuracy (%)  DEM Importance (%)  Aspect Importance (%)  \
# Date
# 2013-04-03              42.0                37.0                   32.0
# 2013-04-29              54.0                37.0                   33.0
# 2013-05-03              59.0                37.0                   33.0
# 2013-05-25              73.0                35.0                   34.0
# 2013-06-01              77.0                35.0                   34.0
#
#             Slope Importance (%)
# Date
# 2013-04-03                  31.0
# 2013-04-29                  30.0
# 2013-05-03                  30.0
# 2013-05-25                  31.0
# 2013-06-01                  31.0

# %%
df.describe()
# Out:
#        RFC Accuracy (%)  DEM Importance (%)  Aspect Importance (%)  \
# count         51.000000           51.000000              51.000000
# mean          61.078431           36.862745              33.137255
# std           16.139198            2.400163               1.980097
# min           32.000000           34.000000              27.000000
# 25%           49.500000           35.000000              32.000000
# 50%           65.000000           36.000000              33.000000
# 75%           73.500000           38.000000              34.000000
# max           86.000000           45.000000              36.000000
#
#        Slope Importance (%)
# count             51.000000
# mean              30.098039
# std                1.100089
# min               28.000000
# 25%               29.000000
# 50%               30.000000
# 75%               31.000000
# max               32.000000

# %%
ax = df.plot(marker='o', linestyle='', figsize=(20,8))

yloc = YearLocator(base=1, month=1, day=1)

ax.yaxis.set_major_locator(yloc)
plt.grid(axis='x', color='k', which='major', linestyle='-', linewidth=2)
ax.grid(True)

# %%
df.plot(marker='o', figsize=(20,8))
